# %%
import sys
import os
import json
import random
from datetime import datetime, timedelta
import traceback
from IPython.display import display, HTML

# Add the project root to Python path
notebook_dir = os.path.dirname(os.path.abspath(''))
project_root = os.path.dirname(notebook_dir)

# Print paths for debugging
print("Notebook directory:", notebook_dir)
print("Project root:", project_root)
print("Current working directory:", os.getcwd())

# Add project root to Python path
if project_root not in sys.path:
    sys.path.append(project_root)

try:
    # Try importing the scraper
    from src.scrapers.kayak import KayakHotelScraper
    print("✅ Successfully imported KayakHotelScraper")
except Exception as e:
    print("❌ Error importing KayakHotelScraper:")
    print(str(e))
    traceback.print_exc()

def print_header(text, level=1):
    """Print formatted header with emojis"""
    emoji_map = {
        'start': '🚀',
        'init': '⚙️',
        'progress': '📊',
        'success': '✅',
        'error': '❌',
        'info': 'ℹ️',
        'warning': '⚠️',
        'save': '💾',
        'complete': '🏁'
    }
    
    prefix = '=' * (level * 2)
    emoji = emoji_map.get(text.lower().split()[0], '📌')
    print(f"\n{prefix} {emoji} {text} {prefix}")

def print_section(text):
    """Print section separator with text"""
    print(f"\n{'='*20} {text} {'='*20}")

def print_hotel_details(hotel):
    """Print detailed hotel information"""
    print("\n📍 Basic Information:")
    print(f"  • Name: {hotel.get('hotel_name', 'N/A')}")
    print(f"  • Location: {hotel.get('location', 'N/A')}")
    print(f"  • Price: {hotel.get('price', 'N/A')}")

    if isinstance(hotel.get('review_scores'), dict):
        print("\n⭐ Ratings & Reviews:")
        scores = hotel['review_scores']
        print(f"  • Rating: {scores.get('rating', 'N/A')}")
        print(f"  • Review Count: {scores.get('count', 'N/A')}")
    
    if hotel.get('rooms'):
        print("\n🛏️ Room Options:")
        for i, room in enumerate(hotel['rooms'], 1):
            print(f"\n  Room Type {i}:")
            print(f"    • Type: {room.get('room_type', 'N/A')}")
            price = room.get('price')
            if isinstance(price, (int, float)):
                print(f"    • Price: ${price:.2f}")
            else:
                print(f"    • Price: {price or 'N/A'}")
            print(f"    • Beds: {room.get('bed_configuration', 'N/A')}")
            print(f"    • Cancellation: {room.get('cancellation_policy', 'N/A')}")
            print(f"    • Board: {room.get('board_type', 'N/A')}")
            if room.get('special_conditions'):
                print("    • Special Conditions:")
                for condition in room['special_conditions']:
                    print(f"      - {condition}")

    if hotel.get('amenities'):
        print("\n🏨 Amenities:")
        for amenity in hotel['amenities'][:10]:  # Show first 10 amenities
            print(f"  • {amenity}")
        if len(hotel['amenities']) > 10:
            print(f"  ... and {len(hotel['amenities']) - 10} more")

    if hotel.get('detail_url'):
        print("\n🔗 Hotel URL:")
        print(f"  {hotel['detail_url']}")
    
    print("\n" + "-"*50)

def test_scraper(limit=7):
    """Test the hotel scraper with detailed logging"""
    print_header("Start Scraper Test")
    
    # Create data directory if it doesn't exist
    os.makedirs('data', exist_ok=True)

    # Set search parameters
    city = "Paris, France"
    check_in = datetime(2025, 1, 10)
    check_out = datetime(2025, 1, 14)

    # Print test configuration
    print(f"\n🌍 Testing configuration:")
    print(f"  • City: {city}")
    print(f"  • Check-in: {check_in.date()}")
    print(f"  • Check-out: {check_out.date()}")
    print(f"  • Hotel limit: {limit}")
    
    try:
        print_header("Initialize Scraper", level=2)
        scraper = KayakHotelScraper(
            city=city,
            check_in_date=check_in,
            check_out_date=check_out
        )

        print_header("Start Scraping", level=2)
        result = scraper.scrape_hotels(limit=limit)
        
        if result and isinstance(result, dict):
            hotels = result.get('hotels', [])
            if hotels:
                print_header("Success", level=2)
                print(f"Successfully scraped {len(hotels)} hotels")
                
                # Save results
                scraper.save_results()
                print("\n💾 Results saved to: data/hotel_data.json")
                
                # Print detailed results
                print_header("Detailed Results", level=2)
                for idx, hotel in enumerate(hotels, 1):
                    print_section(f"Hotel {idx}: {hotel.get('hotel_name', 'Unknown')}")
                    print_hotel_details(hotel)
                    
                # Data file verification
                try:
                    with open('data/hotel_data.json', 'r', encoding='utf-8') as f:
                        saved_data = json.load(f)
                    print(f"\n✅ Verified saved data: {len(saved_data['hotels'])} hotels in JSON file")
                except Exception as e:
                    print(f"\n⚠️ Error verifying saved data: {str(e)}")
                    
            else:
                print_header("Error", level=2)
                print("No hotels were found in the results")
        else:
            print_header("Error", level=2)
            print("No valid results returned from scraper")
        
    except Exception as e:
        print_header("Error", level=2)
        print(f"An error occurred during scraping:")
        print(str(e))
        print("\nFull traceback:")
        traceback.print_exc()
        
    finally:
        try:
            scraper.close()
            print("\n🔒 Scraper closed successfully")
        except:
            print("\n⚠️ Error closing scraper")
        print_header("Complete", level=2)

if __name__ == "__main__":
    # Run the test
    test_scraper()
# Out:
# Notebook directory: /app
# Project root: /
# Current working directory: /app/notebooks
# ✅ Successfully imported KayakHotelScraper
#
# == 🚀 Start Scraper Test ==
#
# 🌍 Testing configuration:
#   • City: Paris, France
#   • Check-in: 2025-01-10
#   • Check-out: 2025-01-14
#   • Hotel limit: 7
#
# ==== 📌 Initialize Scraper ====
# 2025-01-02 21:37:28,942 [INFO] WebDriver initialized successfully
# 2025-01-02 21:37:28,945 [INFO] Loading URL (attempt 1): https://www.kayak.com/hotels/Paris,-France/2025-01-10/2025-01-14/2adults?sort=rank_a
# ==== 🚀 Start Scraping ====
# 2025-01-02 21:38:07,135 [INFO] Found 29 hotels
# 2025-01-02 21:38:17,333 [INFO] Extracted basic info for: Lovely 1 bedroom apartment with indoor fireplace
# 2025-01-02 21:38:17,506 [INFO] Extracted basic info for: L'appart du centre
# 2025-01-02 21:38:28,156 [INFO] Extracted basic info for: Hotel Andrea
# 2025-01-02 21:38:38,260 [INFO] Extracted basic info for: New! Modern and cozy flat. heart of Paris! Swamp center! Halls!
# 2025-01-02 21:38:38,417 [INFO] Extracted basic info for: Studio Victoria - Centre de Paris
# 2025-01-02 21:38:38,587 [INFO] Extracted basic info for: Stunning apartment with view at the very heart of Paris
# 2025-01-02 21:38:38,731 [INFO] Extracted basic info for: Hotel Duo
# 2025-01-02 21:38:38,733 [INFO] Loading detail page: https://www.kayak.com/hotels/Lovely-1-bedroom-apartment-with-indoor-fireplace,Paris-p37687-h1070546032-details/2025-01-10/2025-01-14/2adults?psid=ehEEHjLz6I&pm=daybase#overview
# 2025-01-02 21:38:38,735 [INFO] Loading URL (attempt 1): https://www.kayak.com/hotels/Lovely-1-bedroom-apartment-with-indoor-fireplace,Paris-p37687-h1070546032-details/2025-01-10/2025-01-14/2adults?psid=ehEEHjLz6I&pm=daybase#overview
# 2025-01-02 21
[INFO] Loading URL (attempt 1): https://www.kayak.com/hotels/Paris,-France/2025-01-10/2025-01-14/2adults?sort=rank_a
# 2025-01-02 21:46:32,831 [INFO] Loading detail page: https://www.kayak.com/hotels/Stunning-apartment-with-view-at-the-very-heart-of-Paris,Paris-p37687-h1070433131-details/2025-01-10/2025-01-14/2adults?psid=ehEEHjLz6I&pm=daybase#overview
# 2025-01-02 21:46:32,875 [INFO] Loading URL (attempt 1): https://www.kayak.com/hotels/Stunning-apartment-with-view-at-the-very-heart-of-Paris,Paris-p37687-h1070433131-details/2025-01-10/2025-01-14/2adults?psid=ehEEHjLz6I&pm=daybase#overview
# 2025-01-02 21:47:03,039 [INFO] Successfully extracted 5 images from detail page
# 2025-01-02 21:47:03,042 [INFO] Found 5 detail images
# 2025-01-02 21:47:05,239 [INFO] Found 1 room elements
# 2025-01-02 21:47:26,510 [INFO] Successfully extracted room: All deals
# 2025-01-02 21:47:26,512 [INFO] Found 1 room types
# 2025-01-02 21:47:28,717 [INFO] Successfully extracted 10 amenities
# 2025-01-02 21:47:28,719 [INFO] Found 10 amenities
# 2025-01-02 21:47:28,723 [INFO] Loading URL (attempt 1): https://www.kayak.com/hotels/Paris,-France/2025-01-10/2025-01-14/2adults?sort=rank_a
# 2025-01-02 21:48:09,817 [INFO] Loading detail page: https://www.kayak.com/hotels/Hotel-Duo,Paris-p37687-h157713-details/2025-01-10/2025-01-14/2adults?psid=ehEEHjLz6I&pm=daybase#overview
# 2025-01-02 21:48:09,830 [INFO] Loading URL (attempt 1): https://www.kayak.com/hotels/Hotel-Duo,Paris-p37687-h157713-details/2025-01-10/2025-01-14/2adults?psid=ehEEHjLz6I&pm=daybase#overview
# 2025-01-02 21:48:38,623 [INFO] Successfully extracted 5 images from detail page
# 2025-01-02 21:48:38,627 [INFO] Found 5 detail images
# 2025-01-02 21:48:40,684 [INFO] Found 2 room elements
# 2025-01-02 21:48:41,864 [INFO] Successfully extracted room: Standard Double Room 14m2
# 2025-01-02 21:48:53,018 [INFO] Successfully extracted room: Other deals
# 2025-01-02 21:48:53,020 [INFO] Found 2 room types
# 2025-01-02 21:48:57,658 [INFO] Successfully extracted 10 amenities
# 2025-01-02 21:48:57,660 [INFO] Found 10 amenities
# 2025-01-02 21:48:57,661 [INFO] Loading URL (attempt 1): https://www.kayak.com/hotels/Paris,-France/2025-01-10/2025-01-14/2adults?sort=rank_a
# 2025-01-02 21:49:38,744 [INFO] Data saved successfully to data/hotel_data.json
# ==== ✅ Success ====
# Successfully scraped 7 hotels
#
# 💾 Results saved to: data/hotel_data.json
#
# ==== 📌 Detailed Results ====
#
# ==================== Hotel 1: Lovely 1 bedroom apartment with indoor fireplace ====================
#
# 📍 Basic Information:
#   • Name: Lovely 1 bedroom apartment with indoor fireplace
#   • Location: 0.0 mi from Paris, France
#   • Price: $300
#
# ⭐ Ratings & Reviews:
#   • Rating: None
#   • Review Count: None
#
# 🛏️ Room Options:
#
#   Room Type 1:
#     • Type: All deals
#     • Price: $300.00
#     • Beds: None
#     • Cancellation: None
#     • Board: None
#
# 🏨 Amenities:
#   • Air-conditioned
#   • Fireplace
#   • Coffee grinder
#   • Kettle
#   • Blender
#   • Dishwasher
#   • Ice maker
#   • Free Wi-Fi
#   • Heating
#
# 🔗 Hotel URL:
#   https://www.kayak.com/hotels/Lovely-1-bedroom-apartment-with-indoor-fireplace,Paris-p37687-h1070546032-details/2025-01-10/2025-01-14/2adults?psid=ehEEHjLz6I&pm=daybase#overview
#
# --------------------------------------------------
#
# ==================== Hotel 2: L'appart du centre ====================
#
# 📍 Basic Information:
#   • Name: L'appart du centre
#   • Location: 0.1 mi from Paris, France
#   • Price: $440
#
# ⭐ Ratings & Reviews:
#   • Rating: 9.5
#   • Review Count: 29
#
# 🛏️ Room Options:
#
#   Room Type 1:
#     • Type: All deals
#     • Price: $440.00
#     • Beds: None
#     • Cancellation: None
#     • Board: None
#
# 🏨 Amenities:
#   • Kitchen
#   • Pool table
#   • Air-conditioned
#   • Coffee machine
#   • Washing machine
#   • Linens
#   • Towels
#   • Flat-screen TV
#   • Internet
#   • Hairdryer
#
# 🔗 Hotel URL:
#   https://www.kayak.com/hotels/Lappart-du-centre,Paris-p37687-h9304897-details/2025-01-10/2025-01-14/2adults?psid=ehEEHjLz6I&pm=daybase#overview
#
# --------------------------------------------------
#
# ==================== Hotel 3: Hotel Andrea ====================
#
# 📍 Basic Information:
#   • Name: Hotel Andrea
#   • Location: 0.1 mi from Paris, France
#   • Price: $149
#
# ⭐ Ratings & Reviews:
#   • Rating: None
#   • Review Count: None
#
# 🛏️ Room Options:
#
#   Room Type 1:
#     • Type: Deluxe Double Room
#     • Price: $149.00
#     • Beds: 1 double bed
#     • Cancellation: Free cancellation
#     • Board: None
#
#   Room Type 2:
#     • Type: Other deals
#     • Price: $133.00
#     • Beds: None
#     • Cancellation: Free cancellation
#     • Board: None
#
# 🏨 Amenities:
#   • Room service
#   • Free Wi-Fi
#   • Tea/coffee maker
#   • Coffee machine
#   • Wi-Fi available in all areas
#   • Flat-screen TV
#   • TV
#   • Cable or satellite TV
#   • Free toiletries
#   • Airport shuttle
#
# 🔗 Hotel URL:
#   https://www.kayak.com/hotels/Hotel-Andrea,Paris-p37687-h2531807-details/2025-01-10/2025-01-14/2adults?psid=ehEEHjLz6I&pm=daybase#overview
#
# --------------------------------------------------
#
# ==================== Hotel 4: New! Modern and cozy flat. heart of Paris! Swamp center! Halls! ====================
#
# 📍 Basic Information:
#   • Name: New! Modern and cozy flat. heart of Paris! Swamp center! Halls!
#   • Location: 0.1 mi from Paris, France
#   • Price: $135
#
# ⭐ Ratings & Reviews:
#   • Rating: None
#   • Review Count: None
#
# 🛏️ Room Options:
#
#   Room Type 1:
#     • Type: All deals
#     • Price: $135.00
#     • Beds: None
#     • Cancellation: None
#     • Board: None
#
# 🏨 Amenities:
#   • Kitchen
#   • Air-conditioned
#   • Coffee machine
#   • Washing machine
#   • Clothes dryer
#   • Linens
#   • Towels
#   • TV
#   • Internet
#   • Kid-friendly
#
# 🔗 Hotel URL:
#   https://www.kayak.com/hotels/New-Modern-and-cozy-flat.-heart-of-Paris-Swamp-center-Halls,Paris-p37687-h7285418-details/2025-01-10/2025-01-14/2adults?psid=ehEEHjLz6I&pm=daybase#overview
#
# --------------------------------------------------
#
# ==================== Hotel 5: Studio Victoria - Centre de Paris ====================
#
# 📍 Basic Information:
#   • Name: Studio Victoria - Centre de Paris
#   • Location: 0.1 mi from Paris, France
#   • Price: $195
#
# ⭐ Ratings & Reviews:
#   • Rating: 10.0
#   • Review Count: 6
#
# 🛏️ Room Options:
#
#   Room Type 1:
#     • Type: All deals
#     • Price: $195.00
#     • Beds: None
#     • Cancellation: None
#     • Board: None
#
# 🏨 Amenities:
#   • Kitchen
#   • Air-conditioned
#   • Coffee machine
#   • Washing machine
#   • Tumble dryer
#   • Internet
#   • Cribs available
#   • Microwave
#   • Refrigerator
#   • No smoking
#
# 🔗 Hotel URL:
#   https://www.kayak.com/hotels/Studio-Victoria,Centre-de-Paris,Paris-p37687-h1071862569-details/2025-01-10/2025-01-14/2adults?psid=ehEEHjLz6I&pm=daybase#overview
#
# --------------------------------------------------
#
# ==================== Hotel 6: Stunning apartment with view at the very heart of Paris ====================
#
# 📍 Basic Information:
#   • Name: Stunning apartment with view at the very heart of Paris
#   • Location: 0.1 mi from Paris, France
#   • Price: $340
#
# ⭐ Ratings & Reviews:
#   • Rating: 9.5
#   • Review Count: 36
#
# 🛏️ Room Options:
#
#   Room Type 1:
#     • Type: All deals
#     • Price: $340.00
#     • Beds: None
#     • Cancellation: None
#     • Board: None
#
# 🏨 Amenities:
#   • City view
#   • Kitchen
#   • Air-conditioned
#   • Coffee machine
#   • Laundry facilities
#   • Washing machine
#   • Linens
#   • Towels
#   • Flat-screen TV
#   • TV
#
# 🔗 Hotel URL:
#   https://www.kayak.com/hotels/Stunning-apartment-with-view-at-the-very-heart-of-Paris,Paris-p37687-h1070433131-details/2025-01-10/2025-01-14/2adults?psid=ehEEHjLz6I&pm=daybase#overview
#
# --------------------------------------------------
#
# ==================== Hotel 7: Hotel Duo ====================
#
# 📍 Basic Information:
#   • Name: Hotel Duo
#   • Location: 0.1 mi from Paris, France
#   • Price: $201
#
# ⭐ Ratings & Reviews:
#   • Rating: 8.5
#   • Review Count: 1294
#
# 🛏️ Room Options:
#
#   Room Type 1:
#     • Type: Standard Double Room 14m2
#     • Price: $201.00
#     • Beds: 1 double bed
#     • Cancellation: None
#     • Board: Free breakfast
#
#   Room Type 2:
#     • Type: Other deals
#     • Price: $183.00
#     • Beds: None
#     • Cancellation: None
#     • Board: Free breakfast
#
# 🏨 Amenities:
#   • Fitness center
#   • Bar/Lounge
#   • Room service
#   • Free Wi-Fi
#   • Tea/coffee maker
#   • Coffee machine
#   • Wi-Fi available in all areas
#   • Flat-screen TV
#   • TV
#   • Cable or satellite TV
#
# 🔗 Hotel URL:
#   https://www.kayak.com/hotels/Hotel-Duo,Paris-p37687-h157713-details/2025-01-10/2025-01-14/2adults?psid=ehEEHjLz6I&pm=daybase#overview
#
# --------------------------------------------------
#
# ✅ Verified saved data: 7 hotels in JSON file
# 2025-01-02 21:49:45,432 [INFO] WebDriver closed successfully
# 🔒 Scraper closed successfully
#
# ==== 🏁 Complete ====
