# %%
import sys
import os
import json
import random
from datetime import datetime, timedelta
import traceback
from IPython.display import display, HTML

# Add the project root to Python path
notebook_dir = os.path.dirname(os.path.abspath(''))
project_root = os.path.dirname(notebook_dir)

# Print paths for debugging
print("Notebook directory:", notebook_dir)
print("Project root:", project_root)
print("Current working directory:", os.getcwd())

# Add project root to Python path
if project_root not in sys.path:
    sys.path.append(project_root)

try:
    # Try importing the scraper
    from src.scrapers.kayak import KayakHotelScraper
    print("✅ Successfully imported KayakHotelScraper")
except Exception as e:
    print("❌ Error importing KayakHotelScraper:")
    print(str(e))
    traceback.print_exc()

def print_header(text, level=1):
    """Print formatted header with emojis"""
    emoji_map = {
        'start': '🚀',
        'init': '⚙️',
        'progress': '📊',
        'success': '✅',
        'error': '❌',
        'info': 'ℹ️',
        'warning': '⚠️',
        'save': '💾',
        'complete': '🏁'
    }
    
    prefix = '=' * (level * 2)
    emoji = emoji_map.get(text.lower().split()[0], '📌')
    print(f"\n{prefix} {emoji} {text} {prefix}")

def print_section(text):
    """Print section separator with text"""
    print(f"\n{'='*20} {text} {'='*20}")

def print_hotel_details(hotel):
    """Print detailed hotel information"""
    print("\n📍 Basic Information:")
    print(f"  • Name: {hotel.get('hotel_name', 'N/A')}")
    print(f"  • Location: {hotel.get('location', 'N/A')}")
    print(f"  • Price: {hotel.get('price', 'N/A')}")

    if isinstance(hotel.get('review_scores'), dict):
        print("\n⭐ Ratings & Reviews:")
        scores = hotel['review_scores']
        print(f"  • Rating: {scores.get('rating', 'N/A')}")
        print(f"  • Review Count: {scores.get('count', 'N/A')}")
    
    if hotel.get('rooms'):
        print("\n🛏️ Room Options:")
        for i, room in enumerate(hotel['rooms'], 1):
            print(f"\n  Room Type {i}:")
            print(f"    • Type: {room.get('room_type', 'N/A')}")
            price = room.get('price')
            if isinstance(price, (int, float)):
                print(f"    • Price: ${price:.2f}")
            else:
                print(f"    • Price: {price or 'N/A'}")
            print(f"    • Beds: {room.get('bed_configuration', 'N/A')}")
            print(f"    • Cancellation: {room.get('cancellation_policy', 'N/A')}")
            print(f"    • Board: {room.get('board_type', 'N/A')}")
            if room.get('special_conditions'):
                print("    • Special Conditions:")
                for condition in room['special_conditions']:
                    print(f"      - {condition}")

    if hotel.get('amenities'):
        print("\n🏨 Amenities:")
        for amenity in hotel['amenities'][:10]:  # Show first 10 amenities
            print(f"  • {amenity}")
        if len(hotel['amenities']) > 10:
            print(f"  ... and {len(hotel['amenities']) - 10} more")

    if hotel.get('detail_url'):
        print("\n🔗 Hotel URL:")
        print(f"  {hotel['detail_url']}")
    
    print("\n" + "-"*50)

def test_scraper(limit=5):
    """Test the hotel scraper with detailed logging"""
    print_header("Start Scraper Test")
    
    # Create data directory if it doesn't exist
    os.makedirs('data', exist_ok=True)

    # Set search parameters
    city = "Paris, France"
    check_in = datetime(2025, 1, 10)
    check_out = datetime(2025, 1, 14)

    # Print test configuration
    print(f"\n🌍 Testing configuration:")
    print(f"  • City: {city}")
    print(f"  • Check-in: {check_in.date()}")
    print(f"  • Check-out: {check_out.date()}")
    print(f"  • Hotel limit: {limit}")
    
    try:
        print_header("Initialize Scraper", level=2)
        scraper = KayakHotelScraper(
            city=city,
            check_in_date=check_in,
            check_out_date=check_out
        )

        print_header("Start Scraping", level=2)
        result = scraper.scrape_hotels(limit=limit)
        
        if result and isinstance(result, dict):
            hotels = result.get('hotels', [])
            if hotels:
                print_header("Success", level=2)
                print(f"Successfully scraped {len(hotels)} hotels")
                
                # Save results
                scraper.save_results()
                print("\n💾 Results saved to: data/hotel_data.json")
                
                # Print detailed results
                print_header("Detailed Results", level=2)
                for idx, hotel in enumerate(hotels, 1):
                    print_section(f"Hotel {idx}: {hotel.get('hotel_name', 'Unknown')}")
                    print_hotel_details(hotel)
                    
                # Data file verification
                try:
                    with open('data/hotel_data.json', 'r', encoding='utf-8') as f:
                        saved_data = json.load(f)
                    print(f"\n✅ Verified saved data: {len(saved_data['hotels'])} hotels in JSON file")
                except Exception as e:
                    print(f"\n⚠️ Error verifying saved data: {str(e)}")
                    
            else:
                print_header("Error", level=2)
                print("No hotels were found in the results")
        else:
            print_header("Error", level=2)
            print("No valid results returned from scraper")
        
    except Exception as e:
        print_header("Error", level=2)
        print(f"An error occurred during scraping:")
        print(str(e))
        print("\nFull traceback:")
        traceback.print_exc()
        
    finally:
        try:
            scraper.close()
            print("\n🔒 Scraper closed successfully")
        except:
            print("\n⚠️ Error closing scraper")
        print_header("Complete", level=2)

if __name__ == "__main__":
    # Run the test
    test_scraper()
# Out:
# Notebook directory: /app
# Project root: /
# Current working directory: /app/notebooks
# ✅ Successfully imported KayakHotelScraper
#
# == 🚀 Start Scraper Test ==
#
# 🌍 Testing configuration:
#   • City: Paris, France
#   • Check-in: 2025-01-10
#   • Check-out: 2025-01-14
#   • Hotel limit: 5
#
# ==== 📌 Initialize Scraper ====
# 2025-01-02 15:31:23,745 [INFO] WebDriver initialized successfully
# 2025-01-02 15:31:23,747 [INFO] Loading URL (attempt 1): https://www.kayak.com/hotels/Paris,-France/2025-01-10/2025-01-14/2adults?sort=rank_a
# ==== 🚀 Start Scraping ====
# 2025-01-02 15:32:00,713 [INFO] Found 29 hotels
# 2025-01-02 15:32:10,902 [INFO] Extracted basic info for: Hotel Andrea
# 2025-01-02 15:32:11,044 [INFO] Extracted basic info for: Stunning apartment with view at the very heart of Paris
# 2025-01-02 15:32:11,222 [INFO] Extracted basic info for: Hotel Duo
# 2025-01-02 15:32:21,540 [INFO] Extracted basic info for: D'win
# 2025-01-02 15:32:21,699 [INFO] Extracted basic info for: Marais Lovely
# 2025-01-02 15:32:21,701 [INFO] Loading detail page: https://www.kayak.com/hotels/Hotel-Andrea,Paris-p37687-h2531807-details/2025-01-10/2025-01-14/2adults?psid=eVGkA6x6lV&pm=daybase#overview
# 2025-01-02 15:32:21,703 [INFO] Loading URL (attempt 1): https://www.kayak.com/hotels/Hotel-Andrea,Paris-p37687-h2531807-details/2025-01-10/2025-01-14/2adults?psid=eVGkA6x6lV&pm=daybase#overview
# 2025-01-02 15:32:52,404 [INFO] Successfully extracted 5 images from detail page
# 2025-01-02
[INFO] Loading URL (attempt 1): https://www.kayak.com/hotels/Paris,-France/2025-01-10/2025-01-14/2adults?sort=rank_a
# 2025-01-02 15:38:44,708 [INFO] Loading detail page: https://www.kayak.com/hotels/Marais-Lovely,Paris-p37687-h2349406-details/2025-01-10/2025-01-14/2adults?psid=eVGkA6x6lV&pm=daybase#overview
# 2025-01-02 15:38:44,713 [INFO] Loading URL (attempt 1): https://www.kayak.com/hotels/Marais-Lovely,Paris-p37687-h2349406-details/2025-01-10/2025-01-14/2adults?psid=eVGkA6x6lV&pm=daybase#overview
# 2025-01-02 15:39:13,225 [INFO] Successfully extracted 5 images from detail page
# 2025-01-02 15:39:13,228 [INFO] Found 5 detail images
# 2025-01-02 15:39:15,307 [INFO] Found 3 room elements
# 2025-01-02 15:39:26,903 [INFO] Successfully extracted room: Studio
# 2025-01-02 15:39:38,472 [INFO] Successfully extracted room: Apartment HOTEL DE VILLE
# 2025-01-02 15:39:50,106 [INFO] Successfully extracted room: Apartment NOTRE DAME
# 2025-01-02 15:39:50,109 [INFO] Found 3 room types
# 2025-01-02 15:39:54,627 [INFO] Successfully extracted 10 amenities
# 2025-01-02 15:39:54,629 [INFO] Found 10 amenities
# 2025-01-02 15:39:54,632 [INFO] Loading URL (attempt 1): https://www.kayak.com/hotels/Paris,-France/2025-01-10/2025-01-14/2adults?sort=rank_a
# 2025-01-02 15:40:37,803 [INFO] Data saved successfully to data/hotel_data.json
# ==== ✅ Success ====
# Successfully scraped 5 hotels
#
# 💾 Results saved to: data/hotel_data.json
#
# ==== 📌 Detailed Results ====
#
# ==================== Hotel 1: Hotel Andrea ====================
#
# 📍 Basic Information:
#   • Name: Hotel Andrea
#   • Location: 0.1 mi from Paris, France
#   • Price: $129
#
# ⭐ Ratings & Reviews:
#   • Rating: None
#   • Review Count: None
#
# 🛏️ Room Options:
#
#   Room Type 1:
#     • Type: Deluxe Double Room
#     • Price: $149.00
#     • Beds: 1 double bed
#     • Cancellation: Free cancellation
#     • Board: None
#
#   Room Type 2:
#     • Type: Deluxe Double Room with Balcony
#     • Price: $160.00
#     • Beds: 1 double bed
#     • Cancellation: Free cancellation
#     • Board: None
#
#   Room Type 3:
#     • Type: Deluxe Double Room, Balcony, Executive Level (top floor)
#     • Price: $185.00
#     • Beds: 1 king bed
#     • Cancellation: Free cancellation
#     • Board: None
#
#   Room Type 4:
#     • Type: Other deals
#     • Price: $129.00
#     • Beds: None
#     • Cancellation: Free cancellation
#     • Board: None
#
# 🏨 Amenities:
#   • Room service
#   • Free Wi-Fi
#   • Tea/coffee maker
#   • Coffee machine
#   • Wi-Fi available in all areas
#   • Flat-screen TV
#   • TV
#   • Cable or satellite TV
#   • Free toiletries
#   • Airport shuttle
#
# 🔗 Hotel URL:
#   https://www.kayak.com/hotels/Hotel-Andrea,Paris-p37687-h2531807-details/2025-01-10/2025-01-14/2adults?psid=eVGkA6x6lV&pm=daybase#overview
#
# --------------------------------------------------
#
# ==================== Hotel 2: Stunning apartment with view at the very heart of Paris ====================
#
# 📍 Basic Information:
#   • Name: Stunning apartment with view at the very heart of Paris
#   • Location: 0.1 mi from Paris, France
#   • Price: $340
#
# ⭐ Ratings & Reviews:
#   • Rating: 9.5
#   • Review Count: 36
#
# 🛏️ Room Options:
#
#   Room Type 1:
#     • Type: All deals
#     • Price: $340.00
#     • Beds: None
#     • Cancellation: None
#     • Board: None
#
# 🏨 Amenities:
#   • City view
#   • Kitchen
#   • Air-conditioned
#   • Coffee machine
#   • Laundry facilities
#   • Washing machine
#   • Linens
#   • Towels
#   • Flat-screen TV
#   • TV
#
# 🔗 Hotel URL:
#   https://www.kayak.com/hotels/Stunning-apartment-with-view-at-the-very-heart-of-Paris,Paris-p37687-h1070433131-details/2025-01-10/2025-01-14/2adults?psid=eVGkA6x6lV&pm=daybase#overview
#
# --------------------------------------------------
#
# ==================== Hotel 3: Hotel Duo ====================
#
# 📍 Basic Information:
#   • Name: Hotel Duo
#   • Location: 0.1 mi from Paris, France
#   • Price: $201
#
# ⭐ Ratings & Reviews:
#   • Rating: 8.5
#   • Review Count: 1294
#
# 🛏️ Room Options:
#
#   Room Type 1:
#     • Type: Standard Double Room 14m2
#     • Price: $201.00
#     • Beds: 1 double bed
#     • Cancellation: None
#     • Board: Free breakfast
#
#   Room Type 2:
#     • Type: Standard Twin Room 14m2
#     • Price: $212.00
#     • Beds: 2 twin beds
#     • Cancellation: Free cancellation
#     • Board: None
#
#   Room Type 3:
#     • Type: Superior Twin Room
#     • Price: $222.00
#     • Beds: 2 twin beds
#     • Cancellation: Free cancellation
#     • Board: None
#
#   Room Type 4:
#     • Type: Superior Double Room
#     • Price: $222.00
#     • Beds: 1 double bed
#     • Cancellation: Free cancellation
#     • Board: None
#
#   Room Type 5:
#     • Type: Double Room - Ground Floor 16m2
#     • Price: $246.00
#     • Beds: 1 double bed
#     • Cancellation: Free cancellation
#     • Board: None
#
#   Room Type 6:
#     • Type: Other deals
#     • Price: $188.00
#     • Beds: None
#     • Cancellation: None
#     • Board: Free breakfast
#
# 🏨 Amenities:
#   • Fitness center
#   • Bar/Lounge
#   • Room service
#   • Free Wi-Fi
#   • Tea/coffee maker
#   • Coffee machine
#   • Wi-Fi available in all areas
#   • Flat-screen TV
#   • TV
#   • Cable or satellite TV
#
# 🔗 Hotel URL:
#   https://www.kayak.com/hotels/Hotel-Duo,Paris-p37687-h157713-details/2025-01-10/2025-01-14/2adults?psid=eVGkA6x6lV&pm=daybase#overview
#
# --------------------------------------------------
#
# ==================== Hotel 4: D'win ====================
#
# 📍 Basic Information:
#   • Name: D'win
#   • Location: 0.1 mi from Paris, France
#   • Price: $116
#
# ⭐ Ratings & Reviews:
#   • Rating: None
#   • Review Count: None
#
# 🛏️ Room Options:
#
#   Room Type 1:
#     • Type: Superior Double Room
#     • Price: $116.00
#     • Beds: 1 double bed
#     • Cancellation: Free cancellation
#     • Board: None
#
#   Room Type 2:
#     • Type: Deluxe Double Room
#     • Price: $127.00
#     • Beds: 1 double bed
#     • Cancellation: Free cancellation
#     • Board: None
#
#   Room Type 3:
#     • Type: Comfort Double Room
#     • Price: $134.00
#     • Beds: 1 double bed
#     • Cancellation: Free cancellation
#     • Board: None
#
# 🏨 Amenities:
#   • Bar/Lounge
#   • Room service
#   • Free Wi-Fi
#   • Wi-Fi available in all areas
#   • Flat-screen TV
#   • TV
#   • Cable or satellite TV
#   • Free toiletries
#   • Internet
#   • Pets allowed on request. Charges may apply.
#
# 🔗 Hotel URL:
#   https://www.kayak.com/hotels/Dwin,Paris-p37687-h2014819-details/2025-01-10/2025-01-14/2adults?psid=eVGkA6x6lV&pm=daybase#overview
#
# --------------------------------------------------
#
# ==================== Hotel 5: Marais Lovely ====================
#
# 📍 Basic Information:
#   • Name: Marais Lovely
#   • Location: 0.1 mi from Paris, France
#   • Price: $144
#
# ⭐ Ratings & Reviews:
#   • Rating: 8.7
#   • Review Count: 465
#
# 🛏️ Room Options:
#
#   Room Type 1:
#     • Type: Studio
#     • Price: $144.00
#     • Beds: None
#     • Cancellation: None
#     • Board: None
#
#   Room Type 2:
#     • Type: Apartment HOTEL DE VILLE
#     • Price: $184.00
#     • Beds: None
#     • Cancellation: None
#     • Board: None
#
#   Room Type 3:
#     • Type: Apartment NOTRE DAME
#     • Price: $236.00
#     • Beds: None
#     • Cancellation: None
#     • Board: None
#
# 🏨 Amenities:
#   • Kitchen
#   • Air-conditioned
#   • Coffee machine
#   • Washing machine
#   • Tumble dryer
#   • Towels
#   • Flat-screen TV
#   • TV
#   • Free toiletries
#   • Internet
#
# 🔗 Hotel URL:
#   https://www.kayak.com/hotels/Marais-Lovely,Paris-p37687-h2349406-details/2025-01-10/2025-01-14/2adults?psid=eVGkA6x6lV&pm=daybase#overview
#
# --------------------------------------------------
#
# ✅ Verified saved data: 5 hotels in JSON file
# 2025-01-02 15:40:38,542 [INFO] WebDriver closed successfully
# 🔒 Scraper closed successfully
#
# ==== 🏁 Complete ====
